# %%
import sys, os
import csv

sys.path.insert(0, '../bifacial_radiance')

try:
    from bifacial_radiance_ModelComparison import *
    print "MODIFIED Bifacial Radiance Imported!"
except ImportError:
    raise RuntimeError('bifacial_radiance is required. download distribution')

import sys
sys.path.insert(0, '../../bifacialvf/bifacialvf')

from modelPaper import readSRRL
# Out:
# MODIFIED Bifacial Radiance Imported!

# %%
# Disabling printing inside of Radiance Function because it's too much

import os, sys

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout = self._original_stdout
        
with HiddenPrints():
    print("This will not be printed")

print("This will be printed as before")
# Out:
# This will be printed as before

# %%
#TEST
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="../../bifacialvf/bifacialvf/data/Output/Setup1_Rad.csv"
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Seutp1_Rad.csv"
datestart = '2017-08-12 09:40:00'
dateend = '2017-08-12 10:00:00'
rtr=0.9144
C=0.5
beta = 10

testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# FINISHED FINISHED

# %%
#SETUP 1
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup1_Rad.csv"
datestart = '2017-08-11 17:38:00'
dateend = '2017-08-24 13:59:00'
rtr=0.9144
C=0.5
beta = 10

testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass
print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 8/12 time 18.94
# Warning: sun altitude below zero at month/day 8/13 time 18.93
# Warning: sun altitude below zero at month/day 8/14 time 18.92
# Warning: sun altitude below zero at month/day 8/17 time 18.84
# Warning: sun altitude below zero at month/day 8/18 time 18.83
# Warning: sun altitude below zero at month/day 8/19 time 5.32
# Warning: sun altitude below zero at month/day 8/20 time 18.77
# Warning: sun altitude below zero at month/day 8/21 time 18.75
# Warning: sun altitude below zero at month/day 8/23 time 18.69
# Warning: sun altitude below zero at month/day 8/24 time 5.4
# FINISHED FINISHED

# %%
#SETUP 2
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup2_Rad.csv"
datestart = '2017-08-25 10:00:00'  # Sep. 25 10 am STD time (11 Golden) to end of Aug. 31  
dateend = '2017-09-01 12:59:00'
rtr=0.9144
C=0.36576
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 8/25 time 18.67
# Warning: sun altitude below zero at month/day 8/27 time 18.6
# Warning: sun altitude below zero at month/day 8/28 time 18.58
# Warning: sun altitude below zero at month/day 8/29 time 5.48
# Warning: sun altitude below zero at month/day 8/30 time 18.52
# Warning: sun altitude below zero at month/day 8/31 time 18.5
# FINISHED FINISHED

# %%
#SETUP 3
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup3_Rad.csv"
datestart = '2017-09-02 05:21:00'  
dateend = '2017-09-11 11:59:00'    # 3)Sep. 11 before 12:15 STD time 
rtr=0.9144
C=0.09144
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 9/2 time 18.43
# Warning: sun altitude below zero at month/day 9/3 time 5.56
# Warning: sun altitude below zero at month/day 9/3 time 18.43
# Warning: sun altitude below zero at month/day 9/4 time 5.57
# Warning: sun altitude below zero at month/day 9/5 time 18.36
# Warning: sun altitude below zero at month/day 9/6 time 18.34
# Warning: sun altitude below zero at month/day 9/8 time 5.64
# Warning: sun altitude below zero at month/day 9/8 time 18.27
# Warning: sun altitude below zero at month/day 9/9 time 5.65
# Warning: sun altitude below zero at month/day 9/9 time 18.26
# FINISHED FINISHED

# %%
#SETUP 4
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup4_Rad.csv"
datestart = '2017-09-11 13:00:00'   # 4) Separation "2 m" (4 foot on Reacl)  to...
dateend = '2017-10-3 10:59:00'    #   MAke sure this is the end
rtr=1.2192
C=0.09144
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 9/11 time 18.19
# Warning: sun altitude below zero at month/day 9/12 time 18.18
# Warning: sun altitude below zero at month/day 9/13 time 5.72
# Warning: sun altitude below zero at month/day 9/13 time 18.17
# Warning: sun altitude below zero at month/day 9/14 time 5.73
# Warning: sun altitude below zero at month/day 9/14 time 18.11
# Warning: sun altitude below zero at month/day 9/15 time 18.09
# Warning: sun altitude below zero at month/day 9/16 time 18.08
# Warning: sun altitude below zero at month/day 9/17 time 18.02
# Warning: sun altitude below zero at month/day 9/18 time 5.8
# Warning: sun altitude below zero at month/day 9/18 time 18.01
# Warning: sun altitude below zero at month/day 9/19 time 5.81
# Warning: sun altitude below zero at month/day 9/19 time 18.0
# Warning: sun altitude below zero at month/day 9/20 time 5.82
# Warning: sun altitude below zero at month/day 9/20 time 17.94
# Warning: sun altitude below zero at month/day 9/21 time 17.93
# Warning: sun altitude below zero at month/day 9/22 time 17.87
# Warning: sun altitude below zero at month/day 9/22 time 17.92
# Warning: sun altitude below zero at month/day 9/23 time 5.88
# Warning: sun altitude below zero at month/day 9/23 time 17.86
# Warning: sun altitude below zero at month/day 9/24 time 5.89
# Warning: sun altitude below zero at month/day 9/24 time 17.84
# Warning: sun altitude below zero at month/day 9/25 time 5.9
# Warning: sun altitude below zero at month/day 9/25 time 17.83
# Warning: sun altitude below zero at month/day 9/26 time 17.77
# Warning: sun altitude below zero at month/day 9/27 time 17.77
# Warning: sun altitude below zero at month/day 9/28 time 17.75
# Warning: sun altitude below zero at month/day 9/29 time 5.97
# Warning: sun altitude below zero at month/day 9/29 time 17.69
# Warning: sun altitude below zero at month/day 9/30 time 5.98
# Warning: sun altitude below zero at month/day 9/30 time 17.68
# Warning: sun altitude below zero at month/day 10/1 time 17.62
# Warning: sun altitude below zero at month/day 10/1 time 17.67
# Warning: sun altitude below zero at month/day 10/2 time 17.61
# FINISHED FINISHED

# %%
#SETUP 5
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup5_Rad.csv"
datestart = '2017-10-03 11:00:00'   # 
dateend = '2017-10-08 19:00:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
rtr=1.8288
C=0.09144
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 10/3 time 17.6
# Warning: sun altitude below zero at month/day 10/4 time 6.06
# Warning: sun altitude below zero at month/day 10/4 time 17.58
# Warning: sun altitude below zero at month/day 10/5 time 6.07
# Warning: sun altitude below zero at month/day 10/5 time 17.53
# Warning: sun altitude below zero at month/day 10/6 time 17.52
# Warning: sun altitude below zero at month/day 10/7 time 6.2
# Warning: sun altitude below zero at month/day 10/7 time 6.28
# Warning: sun altitude below zero at month/day 10/7 time 17.51
# Warning: sun altitude below zero at month/day 10/8 time 6.13
# Warning: sun altitude below zero at month/day 10/8 time 17.45
# FINISHED FINISHED

# %%
#SETUP 6
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup6_Rad_Albedo0p56.csv"
datestart = '2017-10-18 15:03:00'   # 
dateend = '2017-10-30 8:39:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
rtr=1.8288
C=0.24384
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.56) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 10/18 time 17.2
# Warning: sun altitude below zero at month/day 10/19 time 6.31
# Warning: sun altitude below zero at month/day 10/19 time 17.19
# Warning: sun altitude below zero at month/day 10/20 time 6.32
# Warning: sun altitude below zero at month/day 10/20 time 17.18
# Warning: sun altitude below zero at month/day 10/21 time 17.12
# Warning: sun altitude below zero at month/day 10/21 time 17.17
# Warning: sun altitude below zero at month/day 10/22 time 17.11
# Warning: sun altitude below zero at month/day 10/23 time 6.38
# Warning: sun altitude below zero at month/day 10/23 time 17.1
# Warning: sun altitude below zero at month/day 10/24 time 6.39
# Warning: sun altitude below zero at month/day 10/24 time 17.09
# Warning: sun altitude below zero at month/day 10/25 time 6.53
# Warning: sun altitude below zero at month/day 10/25 time 17.03
# Warning: sun altitude below zero at month/day 10/26 time 17.02
# Warning: sun altitude below zero at month/day 10/27 time 17.02
# Warning: sun altitude below zero at month/day 10/28 time 6.47
# Warning: sun altitude below zero at month/day 10/28 time 16.95
# Warning: sun altitude below zero at month/day 10/28 time 17.01
# Warning: sun altitude below zero at month/day 10/29 time 6.48
# Warning: sun altitude below zero at month/day 10/29 time 16.95
# FINISHED FINISHED

# %%
#SETUP 7
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup7_Rad_Albedo0p56.csv"
datestart = '2017-10-30 08:49:00'   # 
dateend = '2017-11-13 14:26:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
rtr=1.2192
C=0.24384
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.56) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 10/30 time 16.94
# Warning: sun altitude below zero at month/day 10/31 time 6.54
# Warning: sun altitude below zero at month/day 10/31 time 16.93
# Warning: sun altitude below zero at month/day 11/1 time 6.55
# Warning: sun altitude below zero at month/day 11/1 time 16.87
# Warning: sun altitude below zero at month/day 11/1 time 16.93
# Warning: sun altitude below zero at month/day 11/2 time 6.56
# Warning: sun altitude below zero at month/day 11/2 time 16.87
# Warning: sun altitude below zero at month/day 11/2 time 16.92
# Warning: sun altitude below zero at month/day 11/3 time 16.87
# Warning: sun altitude below zero at month/day 11/4 time 16.85
# Warning: sun altitude below zero at month/day 11/5 time 6.63
# Warning: sun altitude below zero at month/day 11/5 time 16.84
# Warning: sun altitude below zero at month/day 11/6 time 6.64
# Warning: sun altitude below zero at month/day 11/6 time 16.78
# Warning: sun altitude below zero at month/day 11/6 time 16.83
# Warning: sun altitude below zero at month/day 11/7 time 6.65
# Warning: sun altitude below zero at month/day 11/7 time 16.78
# Warning: sun altitude below zero at month/day 11/8 time 16.77
# Warning: sun altitude below zero at month/day 11/9 time 16.77
# Warning: sun altitude below zero at month/day 11/10 time 6.72
# Warning: sun altitude below zero at month/day 11/10 time 16.76
# Warning: sun altitude below zero at month/day 11/11 time 6.73
# Warning: sun altitude below zero at month/day 11/11 time 16.7
# Warning: sun altitude below zero at month/day 11/11 time 16.75
# Warning: sun altitude below zero at month/day 11/12 time 16.7
# Warning: sun altitude below zero at month/day 11/12 time 16.75
# FINISHED FINISHED

# %%
#SETUP 8
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup8_Rad_Albedo0p56.csv"
datestart = '2017-11-13 14:27:00'   # 
dateend = '2017-11-29 9:49:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
dateend = '2017-12-8 9:00:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
rtr=0.9144
C=0.24384
beta = 10
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.56) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 11/13 time 16.7
# Warning: sun altitude below zero at month/day 11/14 time 6.8
# Warning: sun altitude below zero at month/day 11/14 time 16.69
# Warning: sun altitude below zero at month/day 11/15 time 6.81
# Warning: sun altitude below zero at month/day 11/15 time 16.68
# Warning: sun altitude below zero at month/day 11/16 time 6.82
# Warning: sun altitude below zero at month/day 11/16 time 16.68
# Warning: sun altitude below zero at month/day 11/17 time 7.12
# Warning: sun altitude below zero at month/day 11/17 time 16.62
# Warning: sun altitude below zero at month/day 11/17 time 16.68
# Warning: sun altitude below zero at month/day 11/18 time 7.03
# Warning: sun altitude below zero at month/day 11/18 time 16.62
# Warning: sun altitude below zero at month/day 11/18 time 16.67
# Warning: sun altitude below zero at month/day 11/19 time 6.89
# Warning: sun altitude below zero at month/day 11/19 time 16.62
# Warning: sun altitude below zero at month/day 11/20 time 6.9
# Warning: sun altitude below zero at month/day 11/20 time 16.62
# Warning: sun altitude below zero at month/day 11/21 time 16.61
# Warning: sun altitude below zero at month/day 11/22 time 16.6
# Warning: sun altitude below zero at month/day 11/23 time 16.6
# Warning: sun altitude below zero at month/day 11/24 time 6.97
# Warning: sun altitude below zero at month/day 11/24 time 16.59
# Warning: sun altitude below zero at month/day 11/25 time 6.98
# Warning: sun altitude below zero at month/day 11/25 time 16.59
# Warning: sun altitude below zero at month/day 11/26 time 16.59
# Warning: sun altitude below zero at month/day 11/27 time 7.12
# Warning: sun altitude below zero at month/day 11/27 time 16.53
# Warning: sun altitude below zero at month/day 11/27 time 16.58
# Warning: sun altitude below zero at month/day 11/28 time 16.53
# Warning: sun altitude below zero at month/day 11/28 time 16.58
# Warning: sun altitude below zero at month/day 11/29 time 16.03
# Warning: sun altitude below zero at month/day 11/29 time 16.53
# Warning: sun altitude below zero at month/day 11/30 time 16.53
# Warning: sun altitude below zero at month/day 12/1 time 16.53
# Warning: sun altitude below zero at month/day 12/2 time 16.53
# Warning: sun altitude below zero at month/day 12/3 time 16.53
# Warning: sun altitude below zero at month/day 12/4 time 16.52
# Warning: sun altitude below zero at month/day 12/5 time 16.52
# Warning: sun altitude below zero at month/day 12/6 time 16.52
# Warning: sun altitude below zero at month/day 12/7 time 16.52
# FINISHED FINISHED

# %%
#SETUP 9
# Simple example system using Radiance.
#point to an empty directory or existing Radiance directory
writefiletitle="C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\Output\Setup9_Rad.csv"
#123 CHECK DATESTART?
datestart = '2017-11-29 9:49:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
dateend = '2017-12-8 9:00:00'    #  Ignoring data from 10/9 and 10/10 from SNOW
rtr=1.2192
C=0.24384
beta = 30
    
testfolder = r'C:\Users\silvana\Documents\RadianceScene\Test'
SRRLtoread = "C:\Users\Silvana\Documents\GitHub\\bifacialvf\\bifacialvf\data\SRRL_data.csv"
demo = RadianceObj('mini_panel',testfolder)  
demo.setGround(0.62) # input albedo or material name like 'concrete'
#   epwfile = demo.getEPW(37.5,-77.6) #can't run this within NREL firewall.  BOO
metdata = demo.readEPW('EPWs\USA_VA_Richmond.Intl.AP.724010_TMY.epw')
# sky data for index 4010 - 4028 (June 17)  
#demo.gendaylit(metdata,4020)

data = readSRRL(SRRLtoread, decimate = True, decimatestyle = "Mean", decimatevalue = 5 )

# Masking data to only do values we are interested in
mask = (data.index > datestart) & (data.index <= dateend )
data=data.loc[mask]
data=data.dropna()
        
direct_normal = data.loc[:,"Direct"]
diffuse_horizontal = data.loc[:,"Diffuse"]
years=data.loc[:,"Year"]
months=data.loc[:,"Month"]
days=data.loc[:,"Day"]
hours=data.loc[:,"Hour"]
minutes=data.loc[:,"Minute"]
ambient_temperatures=data.loc[:,"Temp"]
wind_speeds=data.loc[:,"Wind"]

noRows=len(direct_normal)         
#    SRRL = ({'Month': month_all, 'Day': day_all, 'Year': year_all, 'Hour': hour_all, 'Minute': minute_all,
#                 'Global': global_all, 'Direct': direct_all, 'Diffuse': diffuse_all, 
#                 'Temp': temp_all, 'Humidity': relhum_all, 'Wind': wind_all})
    
with open (writefiletitle,'w') as csvfile:
    sw = csv.writer(csvfile, delimiter=',', quotechar='|', quoting=csv.QUOTE_MINIMAL)

    outputtitles=['Year', 'Month', 'Day', 'Hour', 'Minute', 'DNI', 'DHI', 'Tamb', 'VWind',
                   'IMT1_Rad', 'IMT2_Rad', 'IMT3_Rad' ,'IMT4_Rad', 'IMT5_Rad', 'IMT6_Rad']
    sw.writerow(outputtitles)

    for rl in range (0, len(data)):
    
        hour=hours[rl]
        minute=minutes[rl]
        day=days[rl]
        month=months[rl]
        year=years[rl]

        my_hour=round((float(hour)+float(minute)/60),2)

        dni= direct_normal[rl]
        dhi= diffuse_horizontal[rl]

        if dni<0:
            dni=0
        if dhi<0:
            dhi=0

        try:
            with HiddenPrints():
                demo.gendaylitSil(month,day, my_hour, dni, dhi)
                #demo.genCumSky(demo.epwfile)
                # create a scene using monopanel in landscape at 10 deg tilt, 1.5m pitch
                sceneDict = {'tilt':beta,'pitch':rtr,'height':C,'orientation':'landscape','azimuth':180}
                scene = demo.makeScene('mini_panel',sceneDict)
                filelist = demo.getfilelist() #filelist now generated in this function
                octfile = demo.makeOct(filelist) 
                analysis = AnalysisObj(octfile, demo.basename)
                OTFDict=analysis.analysisSil(octfile, demo.basename, scene.frontscan, scene.backscan)    

                myfrontlpts=["0 0.0935567365362 0.01 0 0 1\n0 0.187113473072 0.01 0 0 1\n0 0.280670209608 0.01 0 0 1\n0 0.374226946145 0.01 0 0 1\n0 0.467783682681 0.01 0 0 1\n0 0.561340419217 0.01 0 0 1\n0 0.654897155753 0.01 0 0 1\n0 0.748453892289 0.01 0 0 1\n0 0.842010628825 0.01 0 0 1"]
                data_sub = {key:OTFDict[key] for key in ['x', 'y', 'z', 'Wm2', 'mattype']}

            if OTFDict is not None:                
        #                self.Wm2Front = data_sub.pop('Wm2')
        #                data_sub['Wm2Front'] = self.Wm2Front
        #                self.Wm2Back = backR['Wm2']
        #                data_sub['Wm2Back'] = self.Wm2Back
        #                self.backRatio = [x/(y+.001) for x,y in zip(backR['Wm2'],data['Wm2'])] # add 1mW/m2 to avoid dividebyzero
        #                data_sub['Back/FrontRatio'] = self.backRatio
        #                df = pd.DataFrame.from_dict(data_sub)
                outputvalue=[2017, int(month), int(day), int(hour), int(minute), dni, dhi, ambient_temperatures[rl], wind_speeds[rl]]
                outputvalue+=OTFDict['Wm2']
                sw.writerow(outputvalue)
        except:
            print "Warning: sun altitude below zero at month/day " + str(int(month)) + "/" + str(int(day)) + " time " + str(my_hour)
            pass
        

print "FINISHED FINISHED"
# Out:
# path = C:\Users\silvana\Documents\RadianceScene\Test
# Reading SRRL File:  C:\Users\Silvana\Documents\GitHub\bifacialvf\bifacialvf\data\SRRL_data.csv
# Decimation options:  True
# Decimate Style:  Mean  to interval  5  minutes.
# Data decimated to 5 min Interval by Average
# Warning: sun altitude below zero at month/day 11/29 time 16.03
# Warning: sun altitude below zero at month/day 11/29 time 16.53
# Warning: sun altitude below zero at month/day 11/30 time 16.53
# Warning: sun altitude below zero at month/day 12/1 time 16.53
# Warning: sun altitude below zero at month/day 12/2 time 16.53
# Warning: sun altitude below zero at month/day 12/3 time 16.53
# Warning: sun altitude below zero at month/day 12/4 time 16.52
# Warning: sun altitude below zero at month/day 12/5 time 16.52
# Warning: sun altitude below zero at month/day 12/6 time 16.52
# Warning: sun altitude below zero at month/day 12/7 time 16.52
# FINISHED FINISHED
