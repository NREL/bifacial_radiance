# %%
import os
from pathlib import Path

testfolder = 'Simulations/1axis'

if not os.path.exists(testfolder):
    os.makedirs(testfolder)
    
print ("Your simulation will be stored in %s" % testfolder)
# Out:
# Your simulation will be stored in Simulations/1axis

# %%
import bifacial_radiance as br
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# This information helps with debugging and getting support :)
import sys, platform
print("Working on a ", platform.system(), platform.release())
print("Python version ", sys.version)
print("Pandas version ", pd.__version__)
print("bifacial_radiance version ", br.__version__)
print("pyplot ", plt.matplotlib.__version__)
# Out:
# Working on a  Darwin 21.6.0
# Python version  3.11.5 (main, Sep 11 2023, 08:19:27) [Clang 14.0.6 ]
# Pandas version  2.0.3
# bifacial_radiance version  0.4.2+164.ge460768.dirty
# pyplot  3.7.2

# %%
simulationname = '1axis-groundscan'

# Location
lat = 39.7555
lon = -105.2211

# Scene Parameters
azimuth_ang=90 # Facing south
tilt=30

# MakeModule Parameters
moduletype='PVmod'
numpanels=1
module_x = 2 # m
module_y = 1 # m. slope we will measure
sensorsy=2
sensorsground=5

# SceneDict Parameters
pitch = 6 # m
albedo = 0.2
clearance_height = 0.5 # m  
nMods = 4 
nRows = 3

sceneDict = {'tilt':10,'pitch':3,'clearance_height':0.2,'azimuth':180, 'nMods': 20, 'nRows': 7}

# %%
demo = br.RadianceObj(simulationname,path = testfolder)
demo.setGround(albedo)
epwfile = demo.getEPW(lat, lon)
# Out:
# path = Simulations/1axis
# Loading albedo, 1 value(s), 0.200 avg
# 1 nonzero albedo values.
# Getting weather file: USA_CO_Golden-NREL.724666_TMY3.epw
#  ... OK!

# %%
module=demo.makeModule(name=moduletype,x=module_x,y=module_y)
# Out:
# Module Name: PVmod
# Module PVmod updated in module.json
# Pre-existing .rad file objects/PVmod.rad will be overwritten

# %%
metdata = demo.readWeatherFile(epwfile, coerce_year=2021, starttime='2021-06-01', endtime='2021-06-30_23')
# Out:
# 8760 line in WeatherFile. Assuming this is a standard hourly WeatherFile for the year for purposes of saving Gencumulativesky temporary weather files in EPW folder.
# Coercing year to 2021
# Filtering dates
# Saving file EPWs/metdata_temp.csv, # points: 8760
# Calculating Sun position for Metdata that is right-labeled  with a delta of -30 mins. i.e. 12 is 11:30 sunpos

# %%
demo.gendaylit(timeindex=0)
# Out:
# 'skies/sky2_39.74_-105.18_2021-06-01_0500.rad'

# %%
scene = demo.makeScene(module,sceneDict)

# %%
octfile = demo.makeOct()
# Out:
# Created 1axis-groundscan.oct

# %%
analysis = br.AnalysisObj(octfile, demo.name)

# %%
hub_height = 1.5
pitch = 5.7
sazm = 180
fixed_tilt_angle = None
gcr = 2 / pitch
cumulativesky = True

trakerParams = {
    'limit_angle': 50,
    'angledelta': 30,
    'backtrack': True,
    'gcr': gcr,
    'cumulativesky': cumulativesky,
    'azimuth': sazm,
    'fixed_tilt_angle': fixed_tilt_angle
}

# %%
trackerdict = demo.set1axis(**trakerParams)
# Out:
# Saving file EPWs/1axis_-60.0.csv, # points: 90
# Saving file EPWs/1axis_-30.0.csv, # points: 90
# Saving file EPWs/1axis_-0.0.csv, # points: 90
# Saving file EPWs/1axis_30.0.csv, # points: 90
# Saving file EPWs/1axis_60.0.csv, # points: 90

# %%
if cumulativesky:
    demo.genCumSky1axis()
else:
    demo.gendaylit1axis()
# Out:
# message: There were 90 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-60.0.rad
# message: There were 90 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-30.0.rad
# message: There were 89 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_-0.0.rad
# message: There were 90 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_30.0.rad
# message: There were 90 sun up hours in this climate file
# Total Ibh/Lbh: 0.000000
# Created skyfile skies/1axis_60.0.rad

# %%
sceneDict = {
    'pitch': pitch,
    'hub_height': hub_height,
    'nMods': 5,
    'nRows': 2,
    'tilt': fixed_tilt_angle,
    'sazm': sazm
}

# %%
trakerdict = demo.makeScene1axis(module=moduletype, sceneDict=sceneDict)
trakerdict = demo.makeOct1axis()
# Out:
# Making .rad files for cumulativesky 1-axis workflow
# 5 Radfiles created in /objects/
#
# Making 5 octfiles in root directory.
# Created 1axis_-60.0.oct
# Created 1axis_-30.0.oct
# Created 1axis_-0.0.oct
# Created 1axis_30.0.oct
# Created 1axis_60.0.oct

# %%
sensorsgroundvalues = np.array([2, 3, 5, 10, 20, 30, 100, 150, 200, 250, 300, 400, 500])
angles = np.array([-0.0, -30.0, -60.0, 30.0, 60.0])

# %%
resultsdict = {}

for i, sensorsground in enumerate(sensorsgroundvalues):
    print(f"sensorsground: {sensorsground}")
    trakerdict = demo.analysis1axis(customname='1-axis groundscan ' + str(sensorsground), sensorsy=1, modWanted = 2, rowWanted = 1, sensorsground=sensorsground)
    
    for i, angle in enumerate(angles):
        for i, x in enumerate(trakerdict[angle]['Results'][0]['AnalysisObj'].frontx):
            if x >= 1 and x <= pitch-1:
                if (sensorsground, angle) in resultsdict:
                    resultsdict[(sensorsground, angle)] += trakerdict[angle]['Results'][0]['AnalysisObj'].Wm2Front
                else:
                    resultsdict[(sensorsground, angle)] = trakerdict[angle]['Results'][0]['AnalysisObj'].Wm2Front

    print("")
# Out:
# sensorsground: 2
# Linescan in process: 1axis_-60.01-axis groundscan 2_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 2_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 2_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 2_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32816.885. Wm2Back: 5748.446
# Linescan in process: 1axis_-30.01-axis groundscan 2_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 2_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 2_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 2_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 37921.225. Wm2Back: 6299.755
# Linescan in process: 1axis_-0.01-axis groundscan 2_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 2_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 2_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 2_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 27360.999999999996. Wm2Back: 6396.586
# Linescan in process: 1axis_30.01-axis groundscan 2_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 2_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 2_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 2_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 32501.595. Wm2Back: 6143.208
# Linescan in process: 1axis_60.01-axis groundscan 2_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 2_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 2_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 2_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 24965.379999999997. Wm2Back: 5836.875
#
# sensorsground: 3
# Linescan in process: 1axis_-60.01-axis groundscan 3_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 3_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 3_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 3_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32561.656666666666. Wm2Back: 5751.003
# Linescan in process: 1axis_-30.01-axis groundscan 3_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 3_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 3_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 3_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 39053.653333333335. Wm2Back: 6462.651999999999
# Linescan in process: 1axis_-0.01-axis groundscan 3_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 3_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 3_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 3_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 31442.599999999995. Wm2Back: 6430.181
# Linescan in process: 1axis_30.01-axis groundscan 3_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 3_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 3_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 3_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 34931.32666666667. Wm2Back: 6162.254
# Linescan in process: 1axis_60.01-axis groundscan 3_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 3_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 3_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 3_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 23081.933333333334. Wm2Back: 5849.965
#
# sensorsground: 5
# Linescan in process: 1axis_-60.01-axis groundscan 5_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 5_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 5_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 5_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32281.4. Wm2Back: 5738.531
# Linescan in process: 1axis_-30.01-axis groundscan 5_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 5_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 5_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 5_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 39770.434. Wm2Back: 6362.012
# Linescan in process: 1axis_-0.01-axis groundscan 5_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 5_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 5_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 5_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 36151.732. Wm2Back: 6405.233
# Linescan in process: 1axis_30.01-axis groundscan 5_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 5_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 5_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 5_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 32674.917999999998. Wm2Back: 6134.351
# Linescan in process: 1axis_60.01-axis groundscan 5_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 5_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 5_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 5_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 21517.638000000003. Wm2Back: 5893.146
#
# sensorsground: 10
# Linescan in process: 1axis_-60.01-axis groundscan 10_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 10_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 10_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 10_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 33069.424000000006. Wm2Back: 5720.353
# Linescan in process: 1axis_-30.01-axis groundscan 10_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 10_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 10_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 10_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40340.007000000005. Wm2Back: 6307.648
# Linescan in process: 1axis_-0.01-axis groundscan 10_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 10_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 10_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 10_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 37480.31. Wm2Back: 6379.479
# Linescan in process: 1axis_30.01-axis groundscan 10_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 10_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 10_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 10_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 32146.004999999997. Wm2Back: 6160.399
# Linescan in process: 1axis_60.01-axis groundscan 10_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 10_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 10_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 10_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 21078.298000000003. Wm2Back: 5851.394
#
# sensorsground: 20
# Linescan in process: 1axis_-60.01-axis groundscan 20_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 20_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 20_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 20_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 33278.81550000001. Wm2Back: 5709.162
# Linescan in process: 1axis_-30.01-axis groundscan 20_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 20_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 20_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 20_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40647.86200000001. Wm2Back: 6365.238999999999
# Linescan in process: 1axis_-0.01-axis groundscan 20_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 20_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 20_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 20_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 38308.92999999999. Wm2Back: 6365.562000000001
# Linescan in process: 1axis_30.01-axis groundscan 20_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 20_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 20_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 20_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31439.6135. Wm2Back: 6145.145
# Linescan in process: 1axis_60.01-axis groundscan 20_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 20_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 20_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 20_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20953.767. Wm2Back: 5878.687999999999
#
# sensorsground: 30
# Linescan in process: 1axis_-60.01-axis groundscan 30_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 30_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 30_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 30_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 33135.90966666667. Wm2Back: 5732.865999999999
# Linescan in process: 1axis_-30.01-axis groundscan 30_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 30_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 30_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 30_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 41034.761999999995. Wm2Back: 6352.907
# Linescan in process: 1axis_-0.01-axis groundscan 30_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 30_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 30_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 30_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 38647.49833333333. Wm2Back: 6316.256
# Linescan in process: 1axis_30.01-axis groundscan 30_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 30_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 30_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 30_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31581.841000000008. Wm2Back: 6130.681
# Linescan in process: 1axis_60.01-axis groundscan 30_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 30_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 30_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 30_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20768.27833333333. Wm2Back: 5858.714
#
# sensorsground: 100
# Linescan in process: 1axis_-60.01-axis groundscan 100_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 100_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 100_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 100_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32775.69959999999. Wm2Back: 5731.681
# Linescan in process: 1axis_-30.01-axis groundscan 100_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 100_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 100_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 100_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 41198.8543. Wm2Back: 6297.788
# Linescan in process: 1axis_-0.01-axis groundscan 100_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 100_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 100_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 100_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 38901.9994. Wm2Back: 6453.631
# Linescan in process: 1axis_30.01-axis groundscan 100_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 100_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 100_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 100_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31616.3862. Wm2Back: 6130.558
# Linescan in process: 1axis_60.01-axis groundscan 100_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 100_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 100_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 100_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20544.1676. Wm2Back: 5868.625
#
# sensorsground: 150
# Linescan in process: 1axis_-60.01-axis groundscan 150_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 150_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 150_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 150_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32883.34573333333. Wm2Back: 5743.649
# Linescan in process: 1axis_-30.01-axis groundscan 150_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 150_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 150_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 150_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40867.28346666666. Wm2Back: 6378.443
# Linescan in process: 1axis_-0.01-axis groundscan 150_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 150_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 150_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 150_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 38900.392133333335. Wm2Back: 6345.240000000001
# Linescan in process: 1axis_30.01-axis groundscan 150_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 150_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 150_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 150_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31522.089733333327. Wm2Back: 6120.392
# Linescan in process: 1axis_60.01-axis groundscan 150_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 150_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 150_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 150_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20688.8552. Wm2Back: 5863.726
#
# sensorsground: 200
# Linescan in process: 1axis_-60.01-axis groundscan 200_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 200_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 200_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 200_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32940.99995. Wm2Back: 5747.146
# Linescan in process: 1axis_-30.01-axis groundscan 200_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 200_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 200_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 200_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40887.53355. Wm2Back: 6348.873
# Linescan in process: 1axis_-0.01-axis groundscan 200_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 200_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 200_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 200_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 39244.289435. Wm2Back: 6365.956999999999
# Linescan in process: 1axis_30.01-axis groundscan 200_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 200_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 200_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 200_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31037.98705. Wm2Back: 6134.768
# Linescan in process: 1axis_60.01-axis groundscan 200_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 200_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 200_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 200_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20591.7878. Wm2Back: 5881.158
#
# sensorsground: 250
# Linescan in process: 1axis_-60.01-axis groundscan 250_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 250_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 250_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 250_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32243.38376. Wm2Back: 5729.5
# Linescan in process: 1axis_-30.01-axis groundscan 250_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 250_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 250_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 250_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 41182.25192. Wm2Back: 6839.905
# Linescan in process: 1axis_-0.01-axis groundscan 250_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 250_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 250_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 250_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 39284.97876. Wm2Back: 6356.827
# Linescan in process: 1axis_30.01-axis groundscan 250_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 250_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 250_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 250_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31500.33484. Wm2Back: 6151.4710000000005
# Linescan in process: 1axis_60.01-axis groundscan 250_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 250_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 250_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 250_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20504.927079999998. Wm2Back: 5838.263
#
# sensorsground: 300
# Linescan in process: 1axis_-60.01-axis groundscan 300_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 300_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 300_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 300_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 33025.25716666667. Wm2Back: 5733.945
# Linescan in process: 1axis_-30.01-axis groundscan 300_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 300_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 300_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 300_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40603.13256666667. Wm2Back: 6409.187999999999
# Linescan in process: 1axis_-0.01-axis groundscan 300_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 300_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 300_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 300_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 39678.0716. Wm2Back: 6367.71
# Linescan in process: 1axis_30.01-axis groundscan 300_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 300_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 300_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 300_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31666.580966666665. Wm2Back: 6159.78
# Linescan in process: 1axis_60.01-axis groundscan 300_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 300_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 300_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 300_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20548.6497. Wm2Back: 5863.105
#
# sensorsground: 400
# Linescan in process: 1axis_-60.01-axis groundscan 400_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 400_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 400_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 400_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 33085.475825. Wm2Back: 5719.703
# Linescan in process: 1axis_-30.01-axis groundscan 400_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 400_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 400_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 400_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 41608.392325. Wm2Back: 6408.661
# Linescan in process: 1axis_-0.01-axis groundscan 400_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 400_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 400_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 400_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 39210.418524999994. Wm2Back: 6381.692
# Linescan in process: 1axis_30.01-axis groundscan 400_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 400_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 400_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 400_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31350.774899999997. Wm2Back: 6104.065
# Linescan in process: 1axis_60.01-axis groundscan 400_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 400_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 400_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 400_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20554.777275. Wm2Back: 5862.301
#
# sensorsground: 500
# Linescan in process: 1axis_-60.01-axis groundscan 500_Row1_Module2_Front
# Linescan in process: 1axis_-60.01-axis groundscan 500_Row1_Module2_Back
# Saved: results/irr_1axis_-60.01-axis groundscan 500_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-60.01-axis groundscan 500_Row1_Module2_Back.csv
# Index: -60.0. Wm2Front: 32486.04478. Wm2Back: 5745.427
# Linescan in process: 1axis_-30.01-axis groundscan 500_Row1_Module2_Front
# Linescan in process: 1axis_-30.01-axis groundscan 500_Row1_Module2_Back
# Saved: results/irr_1axis_-30.01-axis groundscan 500_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-30.01-axis groundscan 500_Row1_Module2_Back.csv
# Index: -30.0. Wm2Front: 40729.7811. Wm2Back: 6302.369
# Linescan in process: 1axis_-0.01-axis groundscan 500_Row1_Module2_Front
# Linescan in process: 1axis_-0.01-axis groundscan 500_Row1_Module2_Back
# Saved: results/irr_1axis_-0.01-axis groundscan 500_Row1_Module2_Front.csv
# Saved: results/irr_1axis_-0.01-axis groundscan 500_Row1_Module2_Back.csv
# Index: -0.0. Wm2Front: 39506.5545. Wm2Back: 6383.153000000001
# Linescan in process: 1axis_30.01-axis groundscan 500_Row1_Module2_Front
# Linescan in process: 1axis_30.01-axis groundscan 500_Row1_Module2_Back
# Saved: results/irr_1axis_30.01-axis groundscan 500_Row1_Module2_Front.csv
# Saved: results/irr_1axis_30.01-axis groundscan 500_Row1_Module2_Back.csv
# Index: 30.0. Wm2Front: 31437.681080000002. Wm2Back: 6128.828
# Linescan in process: 1axis_60.01-axis groundscan 500_Row1_Module2_Front
# Linescan in process: 1axis_60.01-axis groundscan 500_Row1_Module2_Back
# Saved: results/irr_1axis_60.01-axis groundscan 500_Row1_Module2_Front.csv
# Saved: results/irr_1axis_60.01-axis groundscan 500_Row1_Module2_Back.csv
# Index: 60.0. Wm2Front: 20696.03248. Wm2Back: 5858.092

# %%
trakerdict
# Out:
# {-0.0: {'csvfile': 'EPWs/1axis_-0.0.csv',
#   'surf_azm': 90.00000409455455,
#   'surf_tilt': 0.0,
#   'datetime': Index(['2021-06-01 05:00:00', '2021-06-01 12:00:00', '2021-06-01 13:00:00',
#          '2021-06-02 05:00:00', '2021-06-02 12:00:00', '2021-06-02 13:00:00',
#          '2021-06-03 05:00:00', '2021-06-03 12:00:00', '2021-06-03 13:00:00',
#          '2021-06-04 05:00:00', '2021-06-04 12:00:00', '2021-06-04 13:00:00',
#          '2021-06-05 05:00:00', '2021-06-05 12:00:00', '2021-06-05 13:00:00',
#          '2021-06-06 05:00:00', '2021-06-06 12:00:00', '2021-06-06 13:00:00',
#          '2021-06-07 05:00:00', '2021-06-07 12:00:00', '2021-06-07 13:00:00',
#          '2021-06-08 05:00:00', '2021-06-08 12:00:00', '2021-06-08 13:00:00',
#          '2021-06-09 05:00:00', '2021-06-09 12:00:00', '2021-06-09 13:00:00',
#          '2021-06-10 05:00:00', '2021-06-10 12:00:00', '2021-06-10 13:00:00',
#          '2021-06-11 05:00:00', '2021-06-11 12:00:00', '2021-06-11 13:00:00',
#          '2021-06-12 05:00:00', '2021-06-12 12:00:00', '2021-06-12 13:00:00',
#          '2021-06-13 05:00:00', '2021-06-13 12:00:00', '2021-06-13 13:00:00',
#          '2021-06-14 05:00:00', '2021-06-14 12:00:00', '2021-06-14 13:00:00',
#          '2021-06-15 05:00:00', '2021-06-15 12:00:00', '2021-06-15 13:00:00',
#          '2021-06-16 05:00:00', '2021-06-16 12:00:00', '2021-06-16 13:00:00',
#          '2021-06-17 05:00:00', '2021-06-17 12:00:00', '2021-06-17 13:00:00',
#          '2021-06-18 05:00:00', '2021-06-18 12:00:00', '2021-06-18 13:00:00',
#          '2021-06-19 05:00:00', '2021-06-19 12:00:00', '2021-06-19 13:00:00',
#          '2021-06-20 05:00:00', '2021-06-20 12:00:00', '2021-06-20 13:00:00',
#          '2021-06-21 05:00:00', '2021-06-21 12:00:00', '2021-06-21 13:00:00',
#          '2021-06-22 05:00:00', '2021-06-22 12:00:00', '2021-06-22 13:00:00',
#          '2021-06-23 05:00:00', '2021-06-23 12:00:00', '2021-06-23 13:00:00',
#          '2021-06-24 05:00:00', '2021-06-24 12:00:00', '2021-06-24 13:00:00',
#          '2021-06-25 05:00:00', '2021-06-25 12:00:00', '2021-06-25 13:00:00',
#          '2021-06-26 05:00:00', '2021-06-26 12:00:00', '2021-06-26 13:00:00',
#          '2021-06-27 05:00:00', '2021-06-27 12:00:00', '2021-06-27 13:00:00',
#          '2021-06-28 05:00:00', '2021-06-28 12:00:00', '2021-06-28 13:00:00',
#          '2021-06-29 05:00:00', '2021-06-29 12:00:00', '2021-06-29 13:00:00',
#          '2021-06-30 05:00:00', '2021-06-30 12:00:00', '2021-06-30 13:00:00'],
#         dtype='object'),
#   'count': 90,
#   'skyfile': 'skies/1axis_-0.0.rad',
#   'radfile': 'objects/1axis-0.0__C_1.50000_rtr_5.70000_tilt_0.00000_5modsx2rows_origin0,0.rad',
#   'scene': {'module': {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': 2.01, 'sceney': 1.0, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black PVmod 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects/PVmod.rad', 'glass': False, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}, 'modulefile': 'objects/PVmod.rad', 'hpc': False, 'name': 'Scene0', 'gcr': 0.17543859649122806, 'text': '!xform -rx 0.0 -t 0 0 1.5 -a 5 -t 2.01 0 0 -a 2 -t 0 5.7 0 -i 1 -t -4.02 -0.0 0 -rz 89.99999590544545 -t 0 0 0 objects/PVmod.rad', 'radfiles': 'objects/1axis-0.0__C_1.50000_rtr_5.70000_tilt_0.00000_5modsx2rows_origin0,0.rad', 'sceneDict': {'tilt': 0.0, 'pitch': 5.7, 'clearance_height': 1.5, 'azimuth': 90.00000409455455, 'nMods': 5, 'nRows': 2, 'modulez': 0.02, 'axis_tilt': 0, 'originx': 0, 'originy': 0}},
#   'octfile': '1axis_-0.0.oct',
#   'Results': [{'rowWanted': 1,
#     'modWanted': 2,
#     'AnalysisObj': {'octfile': '1axis_-0.0.oct', 'name': '1axis_-0.01-axis groundscan 500', 'hpc': False, 'modWanted': 2, 'rowWanted': 1, 'Wm2Front': 39506.5545, 'Wm2Back': 6383.153000000001, 'backRatio': 0.1615719953110061, 'frontx': [-1.436416e-07, 0.0114227, 0.02284555, 0.03426839, 0.04569124, 0.05711408, 0.06853693, 0.07995978, 0.09138262, 0.1028055, 0.1142283, 0.1256512, 0.137074, 0.1484969, 0.1599197, 0.1713425, 0.1827654, 0.1941882, 0.2056111, 0.2170339, 0.2284568, 0.2398796, 0.2513025, 0.2627253, 0.2741482, 0
#          '2021-06-20 06:00:00', '2021-06-20 10:00:00', '2021-06-20 11:00:00',
#          '2021-06-21 06:00:00', '2021-06-21 10:00:00', '2021-06-21 11:00:00',
#          '2021-06-22 06:00:00', '2021-06-22 10:00:00', '2021-06-22 11:00:00',
#          '2021-06-23 06:00:00', '2021-06-23 10:00:00', '2021-06-23 11:00:00',
#          '2021-06-24 06:00:00', '2021-06-24 10:00:00', '2021-06-24 11:00:00',
#          '2021-06-25 06:00:00', '2021-06-25 10:00:00', '2021-06-25 11:00:00',
#          '2021-06-26 06:00:00', '2021-06-26 10:00:00', '2021-06-26 11:00:00',
#          '2021-06-27 06:00:00', '2021-06-27 10:00:00', '2021-06-27 11:00:00',
#          '2021-06-28 06:00:00', '2021-06-28 10:00:00', '2021-06-28 11:00:00',
#          '2021-06-29 06:00:00', '2021-06-29 10:00:00', '2021-06-29 11:00:00',
#          '2021-06-30 06:00:00', '2021-06-30 10:00:00', '2021-06-30 11:00:00'],
#         dtype='object'),
#   'count': 90,
#   'skyfile': 'skies/1axis_-30.0.rad',
#   'radfile': 'objects/1axis-30.0__C_1.25000_rtr_5.70000_tilt_30.00000_5modsx2rows_origin0,0.rad',
#   'scene': {'module': {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': 2.01, 'sceney': 1.0, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black PVmod 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects/PVmod.rad', 'glass': False, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}, 'modulefile': 'objects/PVmod.rad', 'hpc': False, 'name': 'Scene0', 'gcr': 0.17543859649122806, 'text': '!xform -rx 30.0 -t 0 0 1.5 -a 5 -t 2.01 0 0 -a 2 -t 0 5.7 0 -i 1 -t -4.02 -0.0 0 -rz 90.0 -t 0 0 0 objects/PVmod.rad', 'radfiles': 'objects/1axis-30.0__C_1.25000_rtr_5.70000_tilt_30.00000_5modsx2rows_origin0,0.rad', 'sceneDict': {'tilt': 30.0, 'pitch': 5.7, 'clearance_height': 1.25, 'azimuth': 90.0, 'nMods': 5, 'nRows': 2, 'modulez': 0.02, 'axis_tilt': 0, 'originx': 0, 'originy': 0}},
#   'octfile': '1axis_-30.0.oct',
#   'Results': [{'rowWanted': 1,
#     'modWanted': 2,
#     'AnalysisObj': {'octfile': '1axis_-30.0.oct', 'name': '1axis_-30.01-axis groundscan 500', 'hpc': False, 'modWanted': 2, 'rowWanted': 1, 'Wm2Front': 40729.7811, 'Wm2Back': 6302.369, 'backRatio': 0.1547361334889145, 'frontx': [-1.23077e-16, 0.01142285, 0.02284569, 0.03426854, 0.04569138, 0.05711423, 0.06853707, 0.07995992, 0.09138277, 0.1028056, 0.1142285, 0.1256513, 0.1370741, 0.148497, 0.1599198, 0.1713427, 0.1827655, 0.1941884, 0.2056112, 0.2170341, 0.2284569, 0.2398798, 0.2513026, 0.2627255, 0.2741483, 0.2855711, 0.296994, 0.3084168, 0.3198397, 0.3312625, 0.3426854, 0.3541082, 0.3655311, 0.3769539, 0.3883768, 0.3997996, 0.4112224, 0.4226453, 0.4340681, 0.445491, 0.4569138, 0.4683367, 0.4797595, 0.4911824, 0.5026052, 0.5140281, 0.5254509, 0.5368
#          '2021-06-23 07:00:00', '2021-06-23 08:00:00', '2021-06-23 09:00:00',
#          '2021-06-24 07:00:00', '2021-06-24 08:00:00', '2021-06-24 09:00:00',
#          '2021-06-25 07:00:00', '2021-06-25 08:00:00', '2021-06-25 09:00:00',
#          '2021-06-26 07:00:00', '2021-06-26 08:00:00', '2021-06-26 09:00:00',
#          '2021-06-27 07:00:00', '2021-06-27 08:00:00', '2021-06-27 09:00:00',
#          '2021-06-28 07:00:00', '2021-06-28 08:00:00', '2021-06-28 09:00:00',
#          '2021-06-29 07:00:00', '2021-06-29 08:00:00', '2021-06-29 09:00:00',
#          '2021-06-30 07:00:00', '2021-06-30 08:00:00', '2021-06-30 09:00:00'],
#         dtype='object'),
#   'count': 90,
#   'skyfile': 'skies/1axis_-60.0.rad',
#   'radfile': 'objects/1axis-60.0__C_1.06699_rtr_5.70000_tilt_60.00000_5modsx2rows_origin0,0.rad',
#   'scene': {'module': {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': 2.01, 'sceney': 1.0, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black PVmod 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects/PVmod.rad', 'glass': False, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}, 'modulefile': 'objects/PVmod.rad', 'hpc': False, 'name': 'Scene0', 'gcr': 0.17543859649122806, 'text': '!xform -rx 60.0 -t 0 0 1.5 -a 5 -t 2.01 0 0 -a 2 -t 0 5.7 0 -i 1 -t -4.02 -0.0 0 -rz 90.0 -t 0 0 0 objects/PVmod.rad', 'radfiles': 'objects/1axis-60.0__C_1.06699_rtr_5.70000_tilt_60.00000_5modsx2rows_origin0,0.rad', 'sceneDict': {'tilt': 60.0, 'pitch': 5.7, 'clearance_height': 1.0669872981077808, 'azimuth': 90.0, 'nMods': 5, 'nRows': 2, 'modulez': 0.02, 'axis_tilt': 0, 'originx': 0, 'originy': 0}},
#   'octfile': '1axis_-60.0.oct',
#   'Results': [{'rowWanted': 1,
#     'modWanted': 2,
#     'AnalysisObj': {'octfile': '1axis_-60.0.oct', 'name': '1axis_-60.01-axis groundscan 500', 'hpc': False, 'modWanted': 2, 'rowWanted': 1, 'Wm2Front': 32486.04478, 'Wm2Back': 5745.427, 'backRatio': 0.176858305221535, 'frontx': [-1.23077e-16, 0.01142285, 0.02284569, 0.03426854, 0.04569138, 0.05711423, 0.06853707, 0.07995992, 0.09138277, 0.1028056, 0.1142285, 0.1256513, 0.1370741, 0.148497, 0.1599198, 0.1713427, 0.1827655, 0.1941884, 0.2056112, 0.2170341, 0.2284569, 0.2398798, 0.2513026, 0.2627255, 0.2741483, 0.2855711, 0.296994, 0.3084168, 0.3198397, 0.3312625, 0.3426854, 0.3541082, 0.3655311, 0.3769539, 0.3883768, 0.3997996, 0.4112224, 0.4226453, 0.4340681, 0.445491, 0.4569138, 0.4683367, 0.4797595, 0.4911824, 0.5026052, 0.5140281, 0.5254509, 0.5368737, 0.5482966, 0.5597194, 0.5711423, 0.5825651, 0.593988, 0.6054108, 0.6168337, 0.6282565, 0.6396794, 0.6511022, 0.6625251, 0.6739479, 0.6853707, 0.6967936, 0.7082164, 0.7196393, 0.7310621, 0.742485, 0.7539078, 0.7653307, 0.7767535, 0.7
#          '2021-06-27 14:00:00', '2021-06-27 15:00:00', '2021-06-27 19:00:00',
#          '2021-06-28 14:00:00', '2021-06-28 15:00:00', '2021-06-28 19:00:00',
#          '2021-06-29 14:00:00', '2021-06-29 15:00:00', '2021-06-29 19:00:00',
#          '2021-06-30 14:00:00', '2021-06-30 15:00:00', '2021-06-30 19:00:00'],
#         dtype='object'),
#   'count': 90,
#   'skyfile': 'skies/1axis_30.0.rad',
#   'radfile': 'objects/1axis30.0__C_1.25000_rtr_5.70000_tilt_-30.00000_5modsx2rows_origin0,0.rad',
#   'scene': {'module': {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': 2.01, 'sceney': 1.0, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black PVmod 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects/PVmod.rad', 'glass': False, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}, 'modulefile': 'objects/PVmod.rad', 'hpc': False, 'name': 'Scene0', 'gcr': 0.17543859649122806, 'text': '!xform -rx -30.0 -t 0 0 1.5 -a 5 -t 2.01 0 0 -a 2 -t 0 5.7 0 -i 1 -t -4.02 -0.0 0 -rz 90.0 -t 0 0 0 objects/PVmod.rad', 'radfiles': 'objects/1axis30.0__C_1.25000_rtr_5.70000_tilt_-30.00000_5modsx2rows_origin0,0.rad', 'sceneDict': {'tilt': -30.0, 'pitch': 5.7, 'clearance_height': 1.25, 'azimuth': 90.0, 'nMods': 5, 'nRows': 2, 'modulez': 0.02, 'axis_tilt': 0, 'originx': 0, 'originy': 0}},
#   'octfile': '1axis_30.0.oct',
#   'Results': [{'rowWanted': 1,
#     'modWanted': 2,
#     'AnalysisObj': {'octfile': '1axis_30.0.oct', 'name': '1axis_30.01-axis groundscan 500', 'hpc': False, 'modWanted': 2, 'rowWanted': 1, 'Wm2Front': 31437.681080000002, 'Wm2Back': 6128.828, 'backRatio': 0.19495165020130517, 'frontx': [-1.23077e-16, 0.01142285, 0.02284569, 0.03426854, 0.04569138, 0.05711423, 0.06853707, 0.07995992, 0.09138277, 0.1028056, 0.1142285, 0.1256513, 0.1370741, 0.148497, 0.1599198, 0.1713427, 0.1827655, 0.1941884, 0.2056112, 0.2170341, 0.2284569, 0.2398798, 0.2513026, 0.2627255, 0.2741483, 0.2855711, 0.296994, 0.3084168, 0.3198397, 0.3312625, 0.3426854, 0.3541082, 0.3655311, 0.3769539, 0.3883768, 0.3997996, 0.4112224, 0.4226453, 0.4340681, 0.445491, 0.4569138, 0.4683367, 0.4797595, 0.4911824, 0.5026052, 0.5140281, 0.5254509, 0.5368737, 0.5482966, 0.5597194, 0.5711423, 0.5825651, 0.593988, 0.6054108, 0.6168337, 0.6282565, 0.6396794, 0.6511022, 0.6625251, 0.6739479, 0.6853707, 0.6967936, 0.7082164, 0.7196393, 0.7310621, 0.742485, 0.7539078, 0.7653307, 0.7767535, 0.7881764, 0.7995992, 0.811022, 0.8224449, 0.8338677, 0.8452906, 0.8567134, 0.8681363, 0.8795591, 0.890982, 0.9024048, 0.9138277, 0.9252505, 0.9366733, 0.9480962, 0.959519, 0.9709419, 0.9823647, 0.9937876, 1.00521, 1.016633, 1.028056, 1.039479, 1.050902, 1.062
#          '2021-06-30 16:00:00', '2021-06-30 17:00:00', '2021-06-30 18:00:00'],
#         dtype='object'),
#   'count': 90,
#   'skyfile': 'skies/1axis_60.0.rad',
#   'radfile': 'objects/1axis60.0__C_1.06699_rtr_5.70000_tilt_-60.00000_5modsx2rows_origin0,0.rad',
#   'scene': {'module': {'x': 2, 'y': 1, 'z': 0.02, 'modulematerial': 'black', 'scenex': 2.01, 'sceney': 1.0, 'scenez': 0.1, 'numpanels': 1, 'bifi': 1, 'text': '! genbox black PVmod 2 1 0.02 | xform -t -1.0 -0.5 0 -a 1 -t 0 1.0 0', 'modulefile': 'objects/PVmod.rad', 'glass': False, 'offsetfromaxis': 0, 'xgap': 0.01, 'ygap': 0.0, 'zgap': 0.1}, 'modulefile': 'objects/PVmod.rad', 'hpc': False, 'name': 'Scene0', 'gcr': 0.17543859649122806, 'text': '!xform -rx -60.0 -t 0 0 1.5 -a 5 -t 2.01 0 0 -a 2 -t 0 5.7 0 -i 1 -t -4.02 -0.0 0 -rz 90.0 -t 0 0 0 objects/PVmod.rad', 'radfiles': 'objects/1axis60.0__C_1.06699_rtr_5.70000_tilt_-60.00000_5modsx2rows_origin0,0.rad', 'sceneDict': {'tilt': -60.0, 'pitch': 5.7, 'clearance_height': 1.0669872981077808, 'azimuth': 90.0, 'nMods': 5, 'nRows': 2, 'modulez': 0.02, 'axis_tilt': 0, 'originx': 0, 'originy': 0}},
#   'octfile': '1axis_60.0.oct',
#   'Results': [{'rowWanted': 1,
#     'modWanted': 2,
#     'AnalysisObj': {'octfile': '1axis_60.0.oct', 'name': '1axis_60.01-axis groundscan 500', 'hpc': False, 'modWanted': 2, 'rowWanted': 1, 'Wm2Front': 20696.03248, 'Wm2Back': 5858.092, 'backRatio': 0.28305385211427475, 'frontx': [-1.23077e-16, 0.01142285, 0.02284569, 0.03426854, 0.04569138, 0.05711423, 0.06853707, 0.07995992, 0.09138277, 0.1028056, 0.1142285, 0.1256513, 0.1370741, 0.148497, 0.1599198, 0.1713427, 0.1827655, 0.1941884, 0.2056112, 0.2170341, 0.2284569, 0.2398798, 0.2513026, 0.2627255, 0.2741483, 0.2855711, 0.296994, 0.3084168, 0.3198397, 0.3312625, 0.3426854, 0.3541082, 0.3655311, 0.3769539, 0.3883768, 0.3997996, 0.4112224, 0.4226453, 0.4340681, 0.445491, 0.4569138, 0.4683367, 0.4797595, 0.4911824, 0.5026052, 0.5140281, 0.5254509, 0.5368737, 0.5482966, 0.5597194, 0.5711423, 0.5825651, 0.593988, 0.6054108, 0.6168337, 0.6282565, 0.6396794, 0.6511022, 0.6625251, 0.6739479, 0.6853707, 0.6967936, 0.7082164, 0.7196393, 0.7310621, 0.742485, 0.7539078, 0.7653307, 0.7767535, 0.7881764, 0.7995992, 0.811022, 0.8224449, 0.8338677, 0.8452906, 0.8567134, 0.8681363, 0.8795591, 0.890982, 0.9024048, 0.9138277, 0.9252505, 0.9366733, 0.9480962, 0.959519, 0.9709419, 0.9823647, 0.9937876, 1.00521, 1.016633, 1.028056, 1.039479, 1.050902, 1.062325, 1.073747, 1.08517, 1.096593, 1.108016, 1.119439, 1.130862, 1.142285, 1.153707, 1.16513, 1.176553, 1.187976, 1.199399, 1.210822, 1.222244, 1.233667, 1.24509, 1.256513, 1.267936, 1.279359, 1.290782, 1.302204, 1.313627, 1.32505, 1.336473, 
#     'backRatio': 0.28305385211427475}]}}

# %%
resulsbyangle = {}

for i, angle in enumerate(angles):
    results = []
    for i, sensorsground in enumerate(sensorsgroundvalues):
        if (sensorsground, angle) in resultsdict:
            results.append(np.mean(resultsdict[(sensorsground, angle)]))
        else:
            results.append(0)
    
    resulsbyangle[angle] = results

# %%
resulsbyangle
# Out:
# {-0.0: [0,
#   31442.599999999995,
#   108455.19600000001,
#   224881.86,
#   459707.1599999999,
#   695654.9699999999,
#   2489727.961600003,
#   3734437.6447999952,
#   5101757.62655001,
#   6364166.5591200115,
#   7697545.890400026,
#   10155498.397974981,
#   12800123.658000028],
#  -30.0: [0,
#   39053.653333333335,
#   119311.302,
#   242040.04200000004,
#   487774.3440000002,
#   738625.7159999999,
#   2636726.675199997,
#   3923259.2127999924,
#   5315379.361499988,
#   6671524.811039991,
#   7877007.717933296,
#   10818182.004500033,
#   13196449.076399935],
#  -60.0: [0,
#   32561.656666666666,
#   96844.20000000001,
#   198416.54400000002,
#   399345.78600000025,
#   596446.3739999998,
#   2097644.7743999967,
#   3156801.1904000035,
#   4282329.993500007,
#   5223428.16912,
#   6406899.890333336,
#   8602223.714499963,
#   10525478.508719971],
#  30.0: [0,
#   34931.32666666667,
#   98024.75399999999,
#   192876.03,
#   377275.36199999996,
#   568473.1380000002,
#   2023448.7168000012,
#   3026120.6143999994,
#   4034938.316500011,
#   5103054.244079998,
#   6143316.70753332,
#   8151201.473999958,
#   10185808.669919968],
#  60.0: [0,
#   23081.933333333334,
#   64552.914000000004,
#   126469.78800000003,
#   251445.20399999994,
#   373829.00999999983,
#   1314826.7264000014,
#   1986130.0992000045,
#   2676932.414000005,
#   3321798.186959993,
#   3986438.041799992,
#   5344242.091499964,
#   6705514.523519959]}

# %%
for i, angle in enumerate(angles):
    df = pd.DataFrame({
        'groundscan': sensorsgroundvalues,
        'average': resulsbyangle[angle]
    })

    df.plot(x='groundscan', y='average', marker='o', color='blue')
    plt.xticks(np.arange(0, 501, 50))
    plt.title(f'Irradiance at different groundscan for 1-axis {angle}')
    plt.show()

# %%
# one graph for all angles
resultsbysensor = {}

for i, sensorsground in enumerate(sensorsgroundvalues):
    resultsarr = []
    for i, angle in enumerate(angles):
        if (sensorsground, angle) in resultsdict:
            resultsarr.append(np.mean(resultsdict[(sensorsground, angle)]))
                          
    resultsbysensor[sensorsground] = np.mean(resultsarr)
# Out:
# /Users/storopov/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/storopov/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
resultsbysensor
# Out:
# {2: nan,
#  3: 32214.233999999997,
#  5: 97437.6732,
#  10: 196936.85280000002,
#  20: 395109.57120000006,
#  30: 594605.8415999999,
#  100: 2112474.97088,
#  150: 3165349.752319999,
#  200: 4282267.542410004,
#  250: 5336794.394063998,
#  300: 6422241.6495999945,
#  400: 8614269.53649498,
#  500: 10682674.88731197}

# %%
df1 = pd.DataFrame({
    'groundscan': sensorsgroundvalues,
    'average': resultsbysensor.values()
})

df1.plot(x='groundscan', y='average', marker='o', color='blue')
plt.xticks(np.arange(0, 501, 50))
plt.title('Cummulative irradiance at different groundscan for 1-axis')
plt.show()
